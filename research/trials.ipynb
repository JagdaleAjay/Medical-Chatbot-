# %%
# %pwd
# Out:
# 'e:\\Medical Chatbot\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'e:\\Medical Chatbot'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# Extract text from PDF files 

def load_pdfs_from_filesystem(pdf_directory):
    loader = DirectoryLoader(pdf_directory, glob="**/*.pdf",loader_cls=PyPDFLoader)
    documents = loader.load()
    return documents

# %%
extracted_data = load_pdf_files("data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 extracted_data = load_pdf_files("data")
#
# NameError: name 'load_pdf_files' is not defined
